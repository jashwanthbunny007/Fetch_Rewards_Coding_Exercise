# %%
import os
import json
import pandas as pd
from datetime import datetime
from ast import literal_eval

# %%
user_data=pd.read_json(r"/users.json",lines=True)

# %%
user_data.head()
# Out:
#                                     _id  active               createdDate  \
# 0  {'$oid': '5ff1e194b6a9d73a3a9f1052'}    True  {'$date': 1609687444800}
# 1  {'$oid': '5ff1e194b6a9d73a3a9f1052'}    True  {'$date': 1609687444800}
# 2  {'$oid': '5ff1e194b6a9d73a3a9f1052'}    True  {'$date': 1609687444800}
# 3  {'$oid': '5ff1e1eacfcf6c399c274ae6'}    True  {'$date': 1609687530554}
# 4  {'$oid': '5ff1e194b6a9d73a3a9f1052'}    True  {'$date': 1609687444800}
#
#                   lastLogin      role signUpSource state
# 0  {'$date': 1609687537858}  consumer        Email    WI
# 1  {'$date': 1609687537858}  consumer        Email    WI
# 2  {'$date': 1609687537858}  consumer        Email    WI
# 3  {'$date': 1609687530597}  consumer        Email    WI
# 4  {'$date': 1609687537858}  consumer        Email    WI

# %%
user_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 495 entries, 0 to 494
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   _id           495 non-null    object
#  1   active        495 non-null    bool
#  2   createdDate   495 non-null    object
#  3   lastLogin     433 non-null    object
#  4   role          495 non-null    object
#  5   signUpSource  447 non-null    object
#  6   state         439 non-null    object
# dtypes: bool(1), object(6)
# memory usage: 23.8+ KB

# %% [markdown]
# Here, If we observe , the "_id" column contains a JSON value, I will fetch the data from the next step

# %%
user_data['_id'] = user_data['_id'].apply(lambda x: x['$oid'])

# %%
user_data.head()
# Out:
#                         _id  active               createdDate  \
# 0  5ff1e194b6a9d73a3a9f1052    True  {'$date': 1609687444800}
# 1  5ff1e194b6a9d73a3a9f1052    True  {'$date': 1609687444800}
# 2  5ff1e194b6a9d73a3a9f1052    True  {'$date': 1609687444800}
# 3  5ff1e1eacfcf6c399c274ae6    True  {'$date': 1609687530554}
# 4  5ff1e194b6a9d73a3a9f1052    True  {'$date': 1609687444800}
#
#                   lastLogin      role signUpSource state
# 0  {'$date': 1609687537858}  consumer        Email    WI
# 1  {'$date': 1609687537858}  consumer        Email    WI
# 2  {'$date': 1609687537858}  consumer        Email    WI
# 3  {'$date': 1609687530597}  consumer        Email    WI
# 4  {'$date': 1609687537858}  consumer        Email    WI

# %%
def extract_date(x):
  try:
    return(datetime.utcfromtimestamp(int(x['$date'])/1000).strftime('%Y-%m-%d %H:%M:%S'))
  except TypeError:
    return(None)

# %% [markdown]
# There's a simlar JSON format found in last login and created date and also these states are in millisecond format. Our next step is to convert it into Date format.

# %%
user_data['createdDate'] = user_data['createdDate'].apply(lambda ms: extract_date(ms))

# %%
user_data['lastLogin'] = user_data['lastLogin'].apply(lambda ms: extract_date(ms))

# %%
user_data.head()
# Out:
#                         _id  active          createdDate            lastLogin  \
# 0  5ff1e194b6a9d73a3a9f1052    True  2021-01-03 15:24:04  2021-01-03 15:25:37
# 1  5ff1e194b6a9d73a3a9f1052    True  2021-01-03 15:24:04  2021-01-03 15:25:37
# 2  5ff1e194b6a9d73a3a9f1052    True  2021-01-03 15:24:04  2021-01-03 15:25:37
# 3  5ff1e1eacfcf6c399c274ae6    True  2021-01-03 15:25:30  2021-01-03 15:25:30
# 4  5ff1e194b6a9d73a3a9f1052    True  2021-01-03 15:24:04  2021-01-03 15:25:37
#
#        role signUpSource state
# 0  consumer        Email    WI
# 1  consumer        Email    WI
# 2  consumer        Email    WI
# 3  consumer        Email    WI
# 4  consumer        Email    WI

# %%
user_data['_id'].unique().size
# Out:
# 212

# %%
user_data['_id'].size
# Out:
# 3465

# %% [markdown]
# This shows there are duplicate values in the files.

# %%
user_data['_id'].duplicated()
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 490     True
# 491     True
# 492     True
# 493     True
# 494     True
# Name: _id, Length: 495, dtype: bool

# %%
user_data.isnull().values.any()
# Out:
# True

# %% [markdown]
# This shows that null values exist, now we'll figure out which values has null values

# %% [markdown]
# this shows the 3 columns lastLogin,signUpSourse ad state has missing values

# %%
print(user_data['_id'].isnull().values.any())
print(user_data['active'].isnull().values.any())
print(user_data['createdDate'].isnull().values.any())
print(user_data['lastLogin'].isnull().values.any())
print(user_data['role'].isnull().values.any())
print(user_data['signUpSource'].isnull().values.any())
print(user_data['state'].isnull().values.any())
# Out:
# False
# False
# False
# True
# False
# True
# True

# %% [markdown]
# Brands Table

# %%
brand_data=pd.read_json(r"/brands.json",lines=True)

# %%
brand_data.head()
# Out:
#                                     _id       barcode        category  \
# 0  {'$oid': '601ac115be37ce2ead437551'}  511111019862          Baking
# 1  {'$oid': '601c5460be37ce2ead43755f'}  511111519928       Beverages
# 2  {'$oid': '601ac142be37ce2ead43755d'}  511111819905          Baking
# 3  {'$oid': '601ac142be37ce2ead43755a'}  511111519874          Baking
# 4  {'$oid': '601ac142be37ce2ead43755e'}  511111319917  Candy & Sweets
#
#        categoryCode                                                cpg  \
# 0            BAKING  {'$id': {'$oid': '601ac114be37ce2ead437550'}, ...
# 1         BEVERAGES  {'$id': {'$oid': '5332f5fbe4b03c9a25efd0ba'}, ...
# 2            BAKING  {'$id': {'$oid': '601ac142be37ce2ead437559'}, ...
# 3            BAKING  {'$id': {'$oid': '601ac142be37ce2ead437559'}, ...
# 4  CANDY_AND_SWEETS  {'$id': {'$oid': '5332fa12e4b03c9a25efd1e7'}, ...
#
#                         name  topBrand                      brandCode
# ...

# %% [markdown]
# Similar to user table, _id colum has json values. We can format it the same way

# %%
brand_data['_id'] = brand_data['_id'].apply(lambda x: x['$oid'])

# %%
brand_data.head()
# Out:
#                         _id       barcode        category      categoryCode  \
# 0  601ac115be37ce2ead437551  511111019862          Baking            BAKING
# 1  601c5460be37ce2ead43755f  511111519928       Beverages         BEVERAGES
# 2  601ac142be37ce2ead43755d  511111819905          Baking            BAKING
# 3  601ac142be37ce2ead43755a  511111519874          Baking            BAKING
# 4  601ac142be37ce2ead43755e  511111319917  Candy & Sweets  CANDY_AND_SWEETS
#
#                                                  cpg  \
# 0  {'$id': {'$oid': '601ac114be37ce2ead437550'}, ...
# 1  {'$id': {'$oid': '5332f5fbe4b03c9a25efd0ba'}, ...
# 2  {'$id': {'$oid': '601ac142be37ce2ead437559'}, ...
# 3  {'$id': {'$oid': '601ac142be37ce2ead437559'}, ...
# 4  {'$id': {'$oid': '5332fa12e4b03c9a25efd1e7'}, ...
#
#                         name  topBrand                      brandCode
# 0  test brand @1612366101024       0.0                            NaN
# ...

# %% [markdown]
# Next data colum that needs attention and formatting is cpg. It has jason data with 2 values id & BAKING. We can split them to 2 columns. This helps is modelling data to database

# %%
brand_cpg=pd.json_normalize(brand_data['cpg'])

# %%
brand_cpg=brand_cpg.rename(columns={'$ref':'cpg.$ref' , '$id.$oid':'cpg.id'})

# %%
brand_merged= pd.merge(brand_data,brand_cpg,left_index=True,right_index=True,how='outer')

# %%
brand_merged.head()
# Out:
#                         _id       barcode        category      categoryCode  \
# 0  601ac115be37ce2ead437551  511111019862          Baking            BAKING
# 1  601c5460be37ce2ead43755f  511111519928       Beverages         BEVERAGES
# 2  601ac142be37ce2ead43755d  511111819905          Baking            BAKING
# 3  601ac142be37ce2ead43755a  511111519874          Baking            BAKING
# 4  601ac142be37ce2ead43755e  511111319917  Candy & Sweets  CANDY_AND_SWEETS
#
#                                                  cpg  \
# 0  {'$id': {'$oid': '601ac114be37ce2ead437550'}, ...
# 1  {'$id': {'$oid': '5332f5fbe4b03c9a25efd0ba'}, ...
# 2  {'$id': {'$oid': '601ac142be37ce2ead437559'}, ...
# 3  {'$id': {'$oid': '601ac142be37ce2ead437559'}, ...
# 4  {'$id': {'$oid': '5332fa12e4b03c9a25efd1e7'}, ...
#
#                         name  topBrand                      brandCode  \
# 0  test brand @1612366101024       0.0                            NaN
# ...

# %% [markdown]
# We can remove cpg column as we have already split them into two columns

# %%
brand_merged=brand_merged.drop(['cpg'],axis=1)
# Out:
#                            _id       barcode            category  \
# 0     601ac115be37ce2ead437551  511111019862              Baking
# 1     601c5460be37ce2ead43755f  511111519928           Beverages
# 2     601ac142be37ce2ead43755d  511111819905              Baking
# 3     601ac142be37ce2ead43755a  511111519874              Baking
# 4     601ac142be37ce2ead43755e  511111319917      Candy & Sweets
# ...                        ...           ...                 ...
# 1162  5f77274dbe37ce6b592e90c0  511111116752              Baking
# 1163  5dc1fca91dda2c0ad7da64ae  511111706328  Breakfast & Cereal
# 1164  5f494c6e04db711dd8fe87e7  511111416173      Candy & Sweets
# 1165  5a021611e4b00efe02b02a57  511111400608             Grocery
# 1166  6026d757be37ce6369301468  511111019930              Baking
#
#           categoryCode                       name  topBrand  \
# 0               BAKING  test brand @1612366101024       0.0
# 1            BEVERAGES                  Starbucks       0.0
# ...

# %% [markdown]
# Out next step is unique value value check for id; this helps during data insertion to database

# %%
brand_merged['_id'].unique().size
# Out:
# 1167

# %%
brand_merged['_id'].size
# Out:
# 1167

# %%
brand_merged['_id'].duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1162    False
# 1163    False
# 1164    False
# 1165    False
# 1166    False
# Name: _id, Length: 1167, dtype: bool

# %% [markdown]
# No duplicate issues with ID. Our next step is to deal with null values. If we find any empty /null they can be either replaced with any default value or set as null based on out requirement.

# %%
brand_merged.isnull().values.any()
# Out:
# True

# %%
print(brand_merged['_id'].isnull().values.any())
print(brand_merged['barcode'].isnull().values.any())
print(brand_merged['category'].isnull().values.any())
print(brand_merged['categoryCode'].isnull().values.any())
print(brand_merged['name'].isnull().values.any())
print(brand_merged['topBrand'].isnull().values.any())
print(brand_merged['brandCode'].isnull().values.any())
print(brand_merged['cpg.$ref'].isnull().values.any())
print(brand_merged['cpg.id'].isnull().values.any())
# Out:
# False
# False
# True
# True
# False
# True
# True
# False
# False

# %% [markdown]
# This shows category,categoryCode, topBrand, brandCode as null values.

# %% [markdown]
# Receipts Table

# %%
receipt_data=pd.read_json(r"/receipts.json",lines=True)

# %%
receipt_data.head()
# Out:
#                                     _id  bonusPointsEarned  \
# 0  {'$oid': '5ff1e1eb0a720f0523000575'}              500.0
# 1  {'$oid': '5ff1e1bb0a720f052300056b'}              150.0
# 2  {'$oid': '5ff1e1f10a720f052300057a'}                5.0
# 3  {'$oid': '5ff1e1ee0a7214ada100056f'}                5.0
# 4  {'$oid': '5ff1e1d20a7214ada1000561'}                5.0
#
#                              bonusPointsEarnedReason  \
# 0  Receipt number 2 completed, bonus point schedu...
# 1  Receipt number 5 completed, bonus point schedu...
# 2                         All-receipts receipt bonus
# 3                         All-receipts receipt bonus
# 4                         All-receipts receipt bonus
#
#                  createDate               dateScanned  \
# 0  {'$date': 1609687531000}  {'$date': 1609687531000}
# 1  {'$date': 1609687483000}  {'$date': 1609687483000}
# 2  {'$date': 1609687537000}  {'$date': 1609687537000}
# 3  {'$date': 1609687534000}  {'$date': 1609687534000}
# ...

# %%
receipt_data['_id'] = user_data['_id'].apply(lambda x: x['$oid'])

# %% [markdown]
# Similar to user table _id has json format; and createDate	, finishedDate, dateScanned, modifyDate, pointsAwardedDate, purchaseDate - has date is in millisecods

# %%
receipt_data['createDate'] = receipt_data['createDate'].apply(lambda ms: extract_date(ms))
receipt_data['finishedDate'] = receipt_data['finishedDate'].apply(lambda ms: extract_date(ms))
receipt_data['dateScanned'] = receipt_data['dateScanned'].apply(lambda ms: extract_date(ms))
receipt_data['modifyDate'] = receipt_data['modifyDate'].apply(lambda ms: extract_date(ms))
receipt_data['pointsAwardedDate'] = receipt_data['pointsAwardedDate'].apply(lambda ms: extract_date(ms))
receipt_data['purchaseDate'] = receipt_data['purchaseDate'].apply(lambda ms: extract_date(ms))

# %%
receipt_data.head()
# Out:
#                         _id  bonusPointsEarned  \
# 0  601ac115be37ce2ead437551              500.0
# 1  601c5460be37ce2ead43755f              150.0
# 2  601ac142be37ce2ead43755d                5.0
# 3  601ac142be37ce2ead43755a                5.0
# 4  601ac142be37ce2ead43755e                5.0
#
#                              bonusPointsEarnedReason           createDate  \
# 0  Receipt number 2 completed, bonus point schedu...  2021-01-03 15:25:31
# 1  Receipt number 5 completed, bonus point schedu...  2021-01-03 15:24:43
# 2                         All-receipts receipt bonus  2021-01-03 15:25:37
# 3                         All-receipts receipt bonus  2021-01-03 15:25:34
# 4                         All-receipts receipt bonus  2021-01-03 15:25:06
#
#            dateScanned         finishedDate           modifyDate  \
# 0  2021-01-03 15:25:31  2021-01-03 15:25:31  2021-01-03 15:25:36
# 1  2021-01-03 15:24:43  2021-01-03 15:24:43  2021-01-03 15:24:48
# ...

# %% [markdown]
# rewardsReceiptItemList - has json formatted data with multiple values

# %% [markdown]
# We can fill na - with null values

# %%
receipt_data = receipt_data.explode('rewardsReceiptItemList')
receipt_data.reset_index(inplace=True)

# %%
receipt_data = receipt_data.fillna({'rewardsReceiptItemList':'{}'})
receipt_data['rewardsReceiptItemList'] = receipt_data['rewardsReceiptItemList'].apply(lambda x:str(x))
receipt_data['rewardsReceiptItemList'] = receipt_data['rewardsReceiptItemList'].apply(literal_eval)

# %%
receipts_new_data = pd.json_normalize(receipt_data['rewardsReceiptItemList'],errors='ignore',record_prefix='rewardsReceiptItemList')\
.add_prefix('rewardsReceiptItemList.')

# %%
receipt_data_merged = pd.merge(receipt_data, receipts_new_data, left_index=True, right_index=True, how='outer')

# %%
receipt_data_merged.head()
# Out:
#    index                       _id  bonusPointsEarned  \
# 0      0  601ac115be37ce2ead437551              500.0
# 1      1  601c5460be37ce2ead43755f              150.0
# 2      1  601c5460be37ce2ead43755f              150.0
# 3      2  601ac142be37ce2ead43755d                5.0
# 4      3  601ac142be37ce2ead43755a                5.0
#
#                              bonusPointsEarnedReason           createDate  \
# 0  Receipt number 2 completed, bonus point schedu...  2021-01-03 15:25:31
# 1  Receipt number 5 completed, bonus point schedu...  2021-01-03 15:24:43
# 2  Receipt number 5 completed, bonus point schedu...  2021-01-03 15:24:43
# 3                         All-receipts receipt bonus  2021-01-03 15:25:37
# 4                         All-receipts receipt bonus  2021-01-03 15:25:34
#
#            dateScanned         finishedDate           modifyDate  \
# 0  2021-01-03 15:25:31  2021-01-03 15:25:31  2021-01-03 15:25:36
# ...

# %% [markdown]
# Our next step is to check uniqueness of id & check for null values.

# %%
receipt_data_merged['_id'].unique().size
# Out:
# 1119

# %%
receipt_data_merged['_id'].size
# Out:
# 7381

# %%
receipt_data_merged['_id'].duplicated()
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 7376    False
# 7377    False
# 7378    False
# 7379     True
# 7380    False
# Name: _id, Length: 7381, dtype: bool

# %% [markdown]
# There are few duplicates which needs to be corrected before uploading to database.

# %%
user_data.isnull().values.any()
# Out:
# True

# %% [markdown]
# Null values of each column can be corrected
